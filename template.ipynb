# %%
import os
from pathlib import Path
import logging

logging.basicConfig(level=logging.INFO, format='[%(asctime)s]: %(message)s:')


project_name = "Summarization_using_NLP"

list_of_files = [
    ".github/workflows/.gitkeep",
    f"src/{project_name}/__init__.py",
    f"src/{project_name}/components/__init__.py",
    f"src/{project_name}/utils/__init__.py",
    f"src/{project_name}/utils/common.py",
    f"src/{project_name}/logging/__init__.py",
    f"src/{project_name}/config/__init__.py",
    f"src/{project_name}/config/configuration.py",
    f"src/{project_name}/pipeline/__init__.py",
    f"src/{project_name}/entity/__init__.py",
    f"src/{project_name}/constants/__init__.py",
    "config/config.yaml",
    "params.yaml",
    "app.py",
    "main.py",
    "Dockerfile",
    "requirements.txt",
    "setup.py",
    "research/trials.ipynb",

]


for filepath in list_of_files:
    filepath = Path(filepath)
    filedir, filename = os.path.split(filepath)

    if filedir != "":
        os.makedirs(filedir, exist_ok=True)
        logging.info(f"Creating directory:{filedir} for the file {filename}")

    
    if (not os.path.exists(filepath)) or (os.path.getsize(filepath) == 0):
        with open(filepath,'w') as f:
            pass
            logging.info(f"Creating empty file: {filepath}")


    
    else:
        logging.info(f"{filename} is already exists")
# Out:
# [2023-07-11 22:29:11,986]: Creating directory:.github\workflows for the file .gitkeep:
# [2023-07-11 22:29:11,988]: Creating empty file: .github\workflows\.gitkeep:
# [2023-07-11 22:29:11,990]: Creating directory:src\Summarization_using_NLP for the file __init__.py:
# [2023-07-11 22:29:11,992]: Creating empty file: src\Summarization_using_NLP\__init__.py:
# [2023-07-11 22:29:11,994]: Creating directory:src\Summarization_using_NLP\components for the file __init__.py:
# [2023-07-11 22:29:11,996]: Creating empty file: src\Summarization_using_NLP\components\__init__.py:
# [2023-07-11 22:29:11,999]: Creating directory:src\Summarization_using_NLP\utils for the file __init__.py:
# [2023-07-11 22:29:12,001]: Creating empty file: src\Summarization_using_NLP\utils\__init__.py:
# [2023-07-11 22:29:12,002]: Creating directory:src\Summarization_using_NLP\utils for the file common.py:
# [2023-07-11 22:29:12,004]: Creating empty file: src\Summarization_using_NLP\utils\common.py:
# [2023-07-11 22:29:12,006]: Creating directory:src\Summarization_using_NLP\logging for the file __init__.py:
# [2023-07-11 22:29:12,026]: Creating empty file: src\Summarization_using_NLP\logging\__init__.py:
# [2023-07-11 22:29:12,026]: Creating directory:src\Summarization_using_NLP\config for the file __init__.py:
# [2023-07-11 22:29:12,026]: Creating empty file: src\Summarization_using_NLP\config\__init__.py:
# [2023-07-11 22:29:12,026]: Creating directory:src\Summarization_using_NLP\config for the file configuration.py:
# [2023-07-11 22:29:12,026]: Creating empty file: src\Summarization_using_NLP\config\configuration.py:
# [2023-07-11 22:29:12,026]: Creating directory:src\Summarization_using_NLP\pipeline for the file __init__.py:
# [2023-07-11 22:29:12,042]: Creating empty file: src\Summarization_using_NLP\pipeline\__init__.py:
# [2023-07-11 22:29:12,042]: Creating directory:src\Summarization_using_NLP\entity for the file __init__.py:
# [2023-07-11 22:29:12,042]: Creating empty file: src\Summarization_using_NLP\entity\__init__.py:
# [2023-07-11 22:29:12,042]: Creating directory:src\Summarization_using_NLP\constants for the file __init__.py:
# [2023-07-11 22:29:12,042]: Creating empty file: src\Summarization_using_NLP\constants\__init__.py:
# [2023-07-11 22:29:12,042]: Creating directory:config for the file config.yaml:
# [2023-07-11 22:29:12,058]: Creating empty file: config\config.yaml:
# [2023-07-11 22:29:12,059]: Creating empty file: params.yaml:
# [2023-07-11 22:29:12,059]: Creating empty file: app.py:
# [2023-07-11 22:29:12,059]: Creating empty file: main.py:
# [2023-07-11 22:29:12,059]: Creating empty file: Dockerfile:
# [2023-07-11 22:29:12,059]: Creating empty file: requirements.txt:
# [2023-07-11 22:29:12,074]: Creating empty file: setup.py:
# [2023-07-11 22:29:12,076]: Creating directory:research for the file trials.ipynb:
# [2023-07-11 22:29:12,076]: Creating empty file: research\trials.ipynb:
